# %%
import pandas as pd
import numpy as np

from quantopian.pipeline import CustomFactor,Pipeline
from quantopian.research import run_pipeline
from quantopian.pipeline.filters import Q1500US
from quantopian.pipeline.data.builtin import USEquityPricing
from quantopian.pipeline.factors import SimpleMovingAverage

# %%
def make_pipeline():

    momentum = Momentum(inputs=[USEquityPricing.close], window_length=250)
    high=momentum.percentile_between(80, 100)
    low=momentum.percentile_between(0,20)
    
    return Pipeline(
        columns={
            'Momentum': momentum,
            'long':high,
            'short':low,
        },
        screen=Q1500US()
    )
class Momentum(CustomFactor):
    def compute(self, today, asset_ids, out, values):
        out[:] = ((values[-1]-values[0])/values[0])

# %%
my_pipe = make_pipeline()
result = run_pipeline(make_pipeline(), '2016-09-25', '2016-09-25')
result.head(1500)
# Out:
#                                                  Momentum   long  short
# 2016-09-26 00:00:00+00:00 Equity(2 [AA])         0.046626  False  False
#                           Equity(24 [AAPL])      0.055564  False  False
#                           Equity(53 [ABMD])      0.388090   True  False
#                           Equity(62 [ABT])       0.095182  False  False
#                           Equity(67 [ADSK])      0.584439   True  False
#                           Equity(76 [TAP])       0.303336  False  False
#                           Equity(114 [ADBE])     0.346361   True  False
#                           Equity(122 [ADI])      0.203737  False  False
#                           Equity(128 [ADM])      0.068589  False  False
#                           Equity(161 [AEP])      0.231367  False  False
#                           Equity(166 [AES])      0.460443   True  False
#                           Equity(168 [AET])      0.098803  False  False
#                           Equity(185 [AFL])      0.292839  False  False
#                           Equity(197 [AGCO])     0.041879  False  False
#                           Equity(216 [HES])     -0.008843  False  False
#                           Equity(239 [AIG])      0.077907  False  False
#                           Equity(266 [AJG])      0.285073  False  False
#                           Equity(270 [AKRX])     0.104119  False  False
#                           Equity(300 [ALK])     -0.148021  False   True
#                           Equity(301 [ALKS])    -0.099691  False   True
#                           Equity(337 [AMAT])     1.076583   True  False
#                           Equity(351 [AMD])      2.945783   True  False
#                           Equity(353 [AME])     -0.066896  False  False
#                           Equity(357 [TWX])      0.177765  False  False
#                           Equity(368 [AMGN])     0.338412   True  False
#                           Equity(405 [AMWD])     0.304186  False  False
#                           Equity(410 [AN])      -0.143008  False   True
#                           Equity(438 [AON])      0.285562  False  False
#                           Equity(448 [APA])      0.653179   True  False
#                           Equity(455 [APC])      0.015589  False  False
# ...                                                   ...    ...    ...
#                           Equity(48091 [VA])     0.586905   True  False
#                           Equity(48103 [STOR])   0.506475   True  False
#                           Equity(48104 [PGRE])   0.057846  False  False
#                           Equity(48169 [KLXI])  -0.057719  False  False
#                           Equity(48220 [LC])    -0.532863  False   True
#                           Equity(48253 [NEWR])   0.010436  False  False
#                           Equity(48317 [JUNO])  -0.245174  False   True
#                           Equity(48384 [QRVO])   0.259353  False  False
#                           Equity(48390 [UE])     0.365437   True  False
#                           Equity(48486 [BOX])    0.179675  False  False
#                           Equity(48531 [VSTO])  -0.072028  False  False
#                           Equity(48543 [SHAK])  -0.248135  False   True
#                           Equity(48547 [ONCE])   0.547160   True  False
#                           Equity(48629 [INOV])  -0.245734  False   True
#                           Equity(48746 [SUM])    0.072539  False  False
#                           Equity(48823 [SEDG])  -0.279224  False   True
#                           Equity(48863 [GDDY])   0.451429   True  False
#                           Equity(48892 [IGT])    0.662519   True  False
#                           Equity(48934 [ETSY])   0.102174  False  False
#                           Equity(48962 [CSAL])   0.968231   True  False
#                           Equity(49003 [TLN])    0.401822   True  False
#                           Equity(49051 [APLE])   0.092653  False  False
#                           Equity(49060 [SHOP])   0.289709  False  False
#                           Equity(49176 [TRU])    0.399543   True  False
#                           Equity(49238 [SRG])    0.364689   True  False
#                           Equity(49242 [PYPL])   0.308195   True  False
#                           Equity(49496 [FDC])         NaN  False  False
#                           Equity(49506 [HPE])         NaN  False  False
#                           Equity(49630 [CSRA])        NaN  False  False
#                           Equity(49700 [FCE_A])       NaN  False  False
#
# [1498 rows x 3 columns]
